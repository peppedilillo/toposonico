# %%
import torch

print("cuda available" if torch.cuda.is_available() else "cuda unavailable")
print("gpu ready" if torch.cuda.device_count() else "only cpu")
# Out:
# cuda available
# gpu ready

# %%
from pathlib import Path

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader

# %%
data_path = Path("..") / "data/engineered/training_pop40_genres.parquet"
_df = pd.read_parquet(data_path)
print(f"Loaded {len(_df):,} tracks from {data_path}")
# Out:
# Loaded 561,314 tracks from ../data/engineered/training_pop40_genres.parquet

# %% [markdown]
# # Data prep

# %%
from ast import literal_eval


df = _df.astype({
    "album_type": "category",
    "_label_size": "float32",
})

if pd.api.types.is_string_dtype(df["_artist_genres"]):
    df["_artist_genres"] = df["_artist_genres"].map(literal_eval)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 561314 entries, 0 to 561313
# Data columns (total 28 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   track_rowid              561314 non-null  int64
#  1   track_name               561314 non-null  string
#  2   artist_name              561314 non-null  string
#  3   artist_rowid             561314 non-null  int64
#  4   album_rowid              561314 non-null  int64
#  5   album_name               561314 non-null  string
#  6   artist_genres            561314 non-null  string
#  7   _artist_genres           561314 non-null  object
#  8   album_type               561314 non-null  category
#  9   _label_size              561314 non-null  float32
#  10  _time_signature_is_four  561314 non-null  bool
#  11  _key_cos                 561314 non-null  float32
#  12  _key_sin                 561314 non-null  float32
#  13  mode                     561314 non-null  bool
#  14  tempo                    561314 non-null  float32
#  15  _release_year            561314 non-null  int16
#  16  _release_yday_cos        561314 non-null  float32
#  17  _release_yday_sin        561314 non-null  float32
#  18  danceability             561314 non-null  float32
#  19  energy                   561314 non-null  float32
#  20  _loudness                561314 non-null  float32
#  21  speechiness              561314 non-null  float32
#  22  acousticness             561314 non-null  float32
#  23  instrumentalness         561314 non-null  float32
#  24  liveness                 561314 non-null  float32
#  25  valence                  561314 non-null  float32
#  26  explicit                 561314 non-null  bool
#  27  duration_ms              561314 non-null  int32
# dtypes: bool(3), category(1), float32(14), int16(1), int32(1), int64(3), object(1), string(4)
# memory usage: 69.6+ MB

# %% [markdown]
# ## Train-valid split
#
# We split selecting artists at random to minimize data leakage from duplicate tracks.

# %%
np.random.seed(0)

artists_unique = df["artist_rowid"].unique()
nartists_train = int(0.8 * len(artists_unique))
artists_train = np.random.choice(artists_unique, replace=False, size=nartists_train)

_shuffled = df.sample(frac=1, replace=False, ignore_index=True, random_state=0)
train_mask = _shuffled["artist_rowid"].isin(artists_train)
dft = _shuffled[train_mask].reset_index(drop=True)
dfv = _shuffled[~train_mask].reset_index(drop=True)

print(f"train amounts to {100 * len(dft) / len(df):.1f} % of the dataset")
# Out:
# train amounts to 80.2 % of the dataset

# %% [markdown]
# ## Indexing genres

# %%
from collections import defaultdict
from ast import literal_eval
from autoencoder.preprocessing import CLEAN_UNKNOWN_GENRE_DEFAULT


def build_genre_vocab(genres: pd.Series) -> defaultdict[str, int]:
    UNKNOWN_INDEX = 0
    vocab = defaultdict(lambda: UNKNOWN_INDEX)
    vocab[CLEAN_UNKNOWN_GENRE_DEFAULT] = UNKNOWN_INDEX
    for gs in genres:
        for g in gs:
            if g not in vocab:
                vocab[g] = len(vocab)
    return vocab

genre2idx = build_genre_vocab(dft["_artist_genres"])
print(f"Found {len(genre2idx)} genres.")
# Out:
# Found 647 genres.

# %%
from collections import Counter

def genre_count(s: pd.Series) -> Counter:
    counter = Counter()
    for gs in s:
        for g in gs:
            counter[g] +=1
    return counter
    
def genre_idx_count(s: pd.Series, genre2idx: dict) -> torch.Tensor:
    counter = genre_count(s)
    cs = [-1] * len(genre2idx)
    for g, i in genre2idx.items():
        cs[i] = counter[g]
    assert -1 not in cs
    return torch.Tensor(cs)

# the plus 1 is added because we are going to use these as weights 
# and it could in principle happen that the unknown genre fallback counts zero.
genre_idx_counts = genre_idx_count(dft["_artist_genres"], genre2idx) + 1.

# %% [markdown]
# ## Standardization

# %%
from sklearn.preprocessing import RobustScaler, MinMaxScaler


ZSCORE_COLS = ["tempo", "duration_ms", "danceability", "energy", "_loudness", "liveness", "valence"]
MINMAX_COLS = ["_release_year", "speechiness", "acousticness", "instrumentalness", "_label_size"]

zscore_scaler = RobustScaler().fit(dft[ZSCORE_COLS])
minmax_scaler = MinMaxScaler(feature_range=(-1, 1)).fit(dft[MINMAX_COLS])

for split_df in [dft, dfv, df]:
    split_df[ZSCORE_COLS] = zscore_scaler.transform(split_df[ZSCORE_COLS])
    split_df[MINMAX_COLS] = minmax_scaler.transform(split_df[MINMAX_COLS])

# %%
if (_plot_train_correlations := True):
    features = [
        "tempo", "duration_ms", "_release_year", "danceability", "energy",
        "_loudness", "speechiness", "acousticness", "instrumentalness",
        "liveness", "valence", "_label_size",
    ]
    n_feat = len(features)
    fig, axes = plt.subplots(n_feat, n_feat, figsize=(12,12))
    
    for i in range(n_feat):
        for j in range(n_feat):
            ax = axes[i, j]
            if i == j:
                ax.hist(dft[features[i]], bins=30, color='steelblue', edgecolor='white')
            else:
                ax.hist2d(dft[features[j]], dft[features[i]], bins=30)
            
            if i == n_feat - 1:
                ax.set_xlabel(features[j], rotation=45, ha='right')
                ax.tick_params(axis='x', labelsize=7, rotation=45)
            else:
                ax.set_xticks([])
                
            if j == 0:
                ax.set_ylabel(features[i])
                ax.tick_params(axis='y', labelsize=7)
            else:
                ax.set_yticks([])
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# # Dataset

# %% [markdown]
#  Album type is kept out of training for now.

# %%
import torch
from torch.utils.data import Dataset


class TrackDataset(Dataset):
    def __init__(self, df: pd.DataFrame, genre2idx: dict[str, int]):
        # genres multi-hot
        self.genres = torch.zeros(len(df), len(genre2idx), dtype=torch.float32)
        for i, gs in enumerate(df["_artist_genres"]):
            for g in gs:
                self.genres[i, genre2idx[g]] = 1.
        # float variables
        self.numeric = torch.tensor(
            df[[
                "_label_size",
                "_release_year",
                "_release_yday_cos",
                "_release_yday_sin",
                "_key_cos", 
                "_key_sin",
                "mode",
                "tempo",
                "_time_signature_is_four",
                "danceability",
                "energy",
                "_loudness",
                "speechiness",
                "acousticness",
                "instrumentalness",
                "liveness",
                "valence",
                "explicit",
                "duration_ms",
            ]].values.astype(float), 
            dtype=torch.float32
        )
        self._len = len(df)

    def __len__(self):
        return self._len

    def __getitem__(self, idx):
        return (
            self.genres[idx],
            self.numeric[idx],
        )

def collate_fn(batch):
    genres, numeric = zip(*batch)
    return {
        "genres": torch.stack(genres),
        "numeric": torch.stack(numeric),
    }

# %% [markdown]
# # Model

# %%
import torch
from torch import nn


class TrackAutoencoder(nn.Module):
    def __init__(
        self,
        ngenres: int,
        nnumeric: int,
        latent_dim: int,
        hidden_dim: list[int],
        genre_embedding_dim: int,
        leaky_relu: float = 0.1,
        dropout: float = 0.1,
    ):
        if not hidden_dim:
            raise ValueError("Requires at least 1 hidden layer.")
        super().__init__()
        self.genre_embedding = nn.Sequential(
            nn.Linear(ngenres, genre_embedding_dim),
            nn.LeakyReLU(leaky_relu),
            nn.Dropout(dropout),
        )
        dim_in = genre_embedding_dim + nnumeric
        self.encoder_input = nn.Sequential(
            nn.Linear(dim_in, hidden_dim[0]),
            nn.LeakyReLU(leaky_relu),
        )
        enc_layers = [
            layer
            for hdin, hdout in zip(hidden_dim[:-1], hidden_dim[1:])
            for layer in (
                nn.Linear(hdin, hdout),
                nn.LeakyReLU(leaky_relu),
                nn.Dropout(dropout),
            )
        ]
        self.encoder_hidden = nn.Sequential(*enc_layers[:-1])  # remove last dropout
        self.encoder_latent = nn.Linear(hidden_dim[-1], latent_dim)

        reversed_dim = hidden_dim[::-1]  # decoder mirrors the encoder
        self.decoder_input = nn.Sequential(
            nn.Linear(latent_dim, reversed_dim[0]),
            nn.LeakyReLU(leaky_relu),
        )
        dec_layers = [
            layer
            for hdin, hdout in zip(reversed_dim[:-1], reversed_dim[1:])
            for layer in (
                nn.Linear(hdin, hdout),
                nn.LeakyReLU(leaky_relu),
            )
        ]
        self.decoder_hidden = nn.Sequential(*dec_layers)
        self.head_genres = nn.Linear(reversed_dim[-1], ngenres)
        self.head_numeric = nn.Linear(reversed_dim[-1], nnumeric)

    def embed(self, batch: dict) -> torch.Tensor:
        return torch.cat((
            self.genre_embedding(batch["genres"]),
            batch["numeric"],
        ), dim=1)

    def encode(self, batch: dict) -> torch.Tensor:
        z = self.encoder_hidden(self.encoder_input(self.embed(batch)))
        return self.encoder_latent(z)
        
    def forward(self, batch: dict):
        zs = self.decoder_hidden(self.decoder_input(self.encode(batch)))
        return {
            "genres": self.head_genres(zs),
            "numeric": self.head_numeric(zs),  
        }

# %% [markdown]
# # Loss

# %%
from typing import Callable


def get_metrics(weights=None, genre_weights=None) -> Callable:
    bce = nn.BCEWithLogitsLoss(pos_weight=genre_weights)
    mse = nn.MSELoss()
    
    wkeys = ["genres", "numeric"]
    if weights is None:
        weights = {}
    elif any([k not in wkeys for k in weights]):
        raise ValueError(f"Wrong key for weights. Allowed keys are: {', '.join(wkeys)}")
    weights |= {k: 1.0 for k in wkeys if k not in weights}

    def compute_batch_metrics(predictions, targets) -> dict:
        # head losses
        l_genres = bce(predictions["genres"], targets["genres"])
        l_numeric = mse(predictions["numeric"], targets["numeric"])
        total = (
            l_numeric * weights["numeric"] +
            l_genres * weights["genres"]
        ) / sum(weights.values())

        # multilabel classifier metrics
        genres_probs = torch.sigmoid(predictions["genres"].detach())
        genres_bpreds = (genres_probs > 0.5).float()
        _tp = (genres_bpreds * targets["genres"]).sum()
        _fp = (genres_bpreds * (1. - targets["genres"])).sum()
        _fn = ((1 - genres_bpreds) * targets["genres"]).sum()
        genres_prc = (_tp) / (_tp + _fp + (eps:=1.e-6))
        genres_rec = (_tp) / (_tp + _fn + eps)
        genres_f1 = 2 * genres_prc * genres_rec / (genres_prc + genres_rec + eps)
        return {
            "total": total,
            "genres": l_genres.item(),
            "numeric": l_numeric.item(),
            "genres_prc": genres_prc.item(),
            "genres_rec": genres_rec.item(),
            "genres_f1": genres_f1.item(),
        }
    
    return compute_batch_metrics

# %% [markdown]
# # Training

# %%
from torch.utils.data import DataLoader
from torch import optim


print("Creating dataloaders..")
train_dataset = TrackDataset(dft, genre2idx=genre2idx)
valid_dataset = TrackDataset(dfv, genre2idx=genre2idx)
train = DataLoader(train_dataset, batch_size=1024, shuffle=True, num_workers=20, pin_memory=True, collate_fn=collate_fn)
valid = DataLoader(valid_dataset, batch_size=1024, num_workers=20, pin_memory=True, collate_fn=collate_fn)
# Out:
# Creating dataloaders..

# %%
MODEL_PARAMETERS = {
    "latent_dim": 128,
    "hidden_dim": [1024, 512, 256],
    "genre_embedding_dim": 256,
    "leaky_relu": 0.1,
    "dropout": 0.1,
}
LOSS_WEIGHTS_PARAMETERS ={ 
    "numeric": 5., 
    "genres": 1.,
}
SCHEDULER_PARAMETERS = {
    "factor": 0.5, 
    "patience": 5,
}
NEPOCHS, LR = 60, 1e-3

# %%
import time
from torch.optim.lr_scheduler import ReduceLROnPlateau

torch.set_float32_matmul_precision('high')


def log_epoch(epoch, t, train_metrics, valid_metrics, best_epoch=None, scheduler=None):
    lr_str = f", LR: {scheduler.get_last_lr()[0]:.1e}" if scheduler else ""
    print(f"\n{'='*5} EPOCH {epoch:02d} (Time: {t:.2f}s{lr_str}) {'='*5}")
    
    header = f"{'Metric':<15} | {'Train':<10} | {'Valid':<10}"
    print(header)
    print("-" * len(header))
    
    for key in train_metrics.keys():
        t_val = train_metrics[key]
        v_val = valid_metrics[key]
        print(f"{key.replace('_', ' ').title():<15} | {t_val:<10.5f} | {v_val:<10.5f}")

    if best_epoch == epoch:
        print("* Best epoch so far!")
        

print("Initializing model..")
history = []
model = TrackAutoencoder(
    ngenres=len(genre2idx),
    nnumeric=train_dataset.numeric.shape[1],
    **MODEL_PARAMETERS,
)
device = torch.device("cuda")
model = model.to(device)
model.compile()
compute_metrics = get_metrics(
    weights=LOSS_WEIGHTS_PARAMETERS,
    genre_weights= (genre_idx_counts.sum() / genre_idx_counts).sqrt().to(device),
)
optimizer = optim.Adam(model.parameters(), lr=LR)
scheduler = ReduceLROnPlateau(optimizer, "min", **SCHEDULER_PARAMETERS)
best_valid_loss = float("inf")
best_state, best_epoch = None, -1
t0 = time.time()
print(f"Training on {len(train_dataset)} rows..")
for epoch in range(NEPOCHS):
    model.train()
    train_metrics = {}
    
    for batch in train:
        batch = {k: v.to(device) for k, v in batch.items()}
        optimizer.zero_grad()

        xs = model(batch)
        batch_metrics = compute_metrics(xs, batch)
        batch_metrics["total"].backward()
        optimizer.step()
        
        for k in batch_metrics.keys():
            val = batch_metrics[k]
            train_metrics.setdefault(k, 0.)
            train_metrics[k] += val.item() if isinstance(val, torch.Tensor) else val
            
    model.eval()
    valid_metrics = {}
    with torch.no_grad():
        for batch in valid:
            batch = {k: v.to(device) for k, v in batch.items()}
            xs = model(batch)
            batch_metrics = compute_metrics(xs, batch)
            
            for k in batch_metrics.keys():
                val = batch_metrics[k]
                valid_metrics.setdefault(k, 0.)
                valid_metrics[k] += val.item() if isinstance(val, torch.Tensor) else val
    
    avg_train = {k: v / len(train) for k, v in train_metrics.items()}
    avg_valid = {k: v / len(valid) for k, v in valid_metrics.items()}
    scheduler.step(avg_valid["total"])
    if avg_valid["total"] < best_valid_loss:
        best_valid_loss = avg_valid["total"]
        best_epoch = epoch
        best_state = model.state_dict()
    if epoch % (PRINT_EVERY := 1) == 0: 
        log_epoch(epoch, time.time() - t0, avg_train, avg_valid, best_epoch, scheduler)
        history.append((avg_train, avg_valid))
    if scheduler.get_last_lr()[0] <= 2e-6:
        print("Minimum LR reached. Breaking.")
        break
        
model.load_state_dict(best_state)
print(f"Restored best model (valid loss: {best_valid_loss:.5f}, epoch: {best_epoch})")
# Out:
# Initializing model..
# Training on 449921 rows..
#
# ===== EPOCH 00 (Time: 5.43s, LR: 1.0e-03) =====
# Metric          | Train      | Valid
# -----------------------------------------
# Total           | 0.10547    | 0.02341
# Genres          | 0.17902    | 0.09776
# Numeric         | 0.09076    | 0.00855
# Genres Prc      | 0.19716    | 0.15773
# Genres Rec      | 0.31352    | 0.64468
# Genres F1       | 0.20159    | 0.25341
# * Best epoch so far!
#
# ===== EPOCH 01 (Time: 9.65s, LR: 1.0e-03) =====
# Metric          | Train      | Valid
# -----------------------------------------
# Total           | 0.01831    | 0.01270
# Genres          | 0.06493    | 0.05136
# Numeric         | 0.00899    | 0.00497
# Genres Prc      | 0.20594    | 0.24312
# Genres Rec      | 0.79404    | 0.87348
# Genres F1       | 0.32687    | 0.38034
# * Best epoch so far!
#
# ===== EPOCH 02 (Time: 13.90s, LR: 1.0e-03) =====
# Metric          | Train      | Valid
# -----------------------------------------
# Total           | 0.01135    | 0.00886
# Genres          | 0.03528    | 0.03345
# Numeric         | 0.00656    | 0.00394
# Genres Prc      | 0.30341    | 0.33648
# Genres Rec      | 0.92272    | 0.93617
# Genres F1       | 0.45623    | 0.49498
# * Best epoch so far!
#
# ===== EPOCH 03 (Time: 18.16s, LR: 1.0e-03) =====
# Metric          | Train      | Valid
# -----------------------------------------
# Total           | 0.00861    | 0.00674
# Genres          | 0.02409    | 0.02628
# Numeric         | 0.00552    | 0.00284
# Genres Prc      | 0.37994    | 0.40375
# Genres Rec      | 0.95683    | 0.95405
# Genres F1       | 0.54360    | 0.56733
# * Best epoch so far!
#
# ===== EPOCH 04 (Time: 22.43s, LR: 1.0e-03) =====
# Metric          | Train      | Valid
# -----------------------------------------
# Total           | 0.00707    | 0.00585
# Genres          | 0.01819    | 0.02201
# Numeric         | 0.00484    | 0.00262
# Genres Prc      | 0.44469    | 0.44890
# Genres Rec      | 0.97090    | 0.96501
# Genres F1       | 0.60973    | 0.61269
# * Best epoch so far!
#
# ===== EPOCH 05 (Time: 26.68s, LR: 1.0e-03) =====
# Metric          | Train      | Valid
# -----------------------------------------
# Total           | 0.00594    | 0.00508
# Genres          | 0.01418    | 0.01928
# Numeric         | 0.00429    | 0.00224
# Genres Prc      | 0.50487    | 0.52249
# Genres Rec      | 0.97957    | 0.96917
# Genres F1       | 0.66610    | 0.67888
# * Best epoch so far!
#
# ===== EPOCH 06 (Time: 30.91s, LR: 1.0e-03) =====
# Metric          | Train      | Valid
# -----------------------------------------
# Total           | 0.00508    | 0.00464
# Genres          | 0.01135    | 0.01726
# Numeric         | 0.00382    | 0.00212
# Genres Prc      | 0.56095    | 0.58147
# Genres Rec      | 0.98483    | 0.97222
# Genres F1       | 0.71456    | 0.72765
# * Best epoch so far!
#
# ===== EPOCH 07 (Time: 35.21s, LR: 1.0e-03) =====
# Metric          | Train      | Valid
# -----------------------------------------
# Total           | 0.00453    | 0.00447
# Genres          | 0.00945    | 0.01545
# Numeric         | 0.00354    | 0.00228
# Genres Prc      | 0.60678    | 0.61509
# Genres Rec      | 0.98810    | 0.97507
# Genres F1       | 0.75172    | 0.75428
# * Best epoch so far!
#
# ===== EPOCH 08 (Time: 39.54s, LR: 1.0e-03) =====
# Metric          | Train      | Valid
# -----------------------------------------
# Total           | 0.00404    | 0.00407
# Genres          | 0.00812    | 0.01482
# Numeric         | 0.00322    | 0.00192
# Genres Prc      | 0.64320    | 0.63878
# Genres Rec      | 0.99019    | 0.97691
# Genres F1       | 0.77972    | 0.77241
# * Best epoch so far!
#
# ===== EPOCH 09 (Time: 43.86s, LR: 1.0e-03) =====
# Metric          | Train      | Valid
# -----------------------------------------
# Total           | 0.00375    | 0.00376
# Genres          | 0.00717    | 0.01400
# Numeric         | 0.00306    | 0.00171
# Genres Prc      | 0.67264    | 0.67240
# Genres Rec      | 0.99128    | 0.97678
# Genres F1       | 0.80135    | 0.79645
# * Best epoch so far!
#
# ===== EPOCH 10 (Time: 48.19s, LR: 1.0e-03) =====
# Metric          | Train      | Valid
# -----------------------------------------
# Total           | 0.00345    | 0.00366
# Genres          | 0.00638    | 0.01379
# Numeric         | 0.00286    | 0.00164
# Genres Prc      | 0.69826    | 0.69470
# Genres Rec      | 0.99247    | 0.97777
# Genres F1       | 0.81966    | 0.81223
# * Best epoch so far!
#
# ===== EPOCH 11 (Time: 52.47s, LR: 1.0e-03) =====
# Metric          | Train      | Valid
# -----------------------------------------
# Total           | 0.00320    | 0.00379
# Genres          | 0.00568    | 0.01363
# Numeric         | 0.00270    | 0.00182
# Genres Prc      | 0.72287    | 0.70680
# Genres Rec      | 0.99332    | 0.97864
# Genres F1       | 0.83669    | 0.82074
#
# ===== EPOCH 12 (Time: 56.72s, LR: 1.0e-03) =====
# Metric          | Train      | Valid
# -----------------------------------------
# Total           | 0.00301    | 0.00339
# Genres          | 0.00515    | 0.01337
# Numeric         | 0.00258    | 0.00139
# Genres Prc      | 0.74282    | 0.75371
# Genres Rec      | 0.99394    | 0.97656
# Genres F1       | 0.85014    | 0.85074
# * Best epoch so far!
#
# ===== EPOCH 13 (Time: 61.03s, LR: 1.0e-03) =====
# Metric          | Train      | Valid
# -----------------------------------------
# Total           | 0.00284    | 0.00352
# Genres          | 0.00468    | 0.01343
# Numeric         | 0.00247    | 0.00154
# Genres Prc      | 0.76060    | 0.74649
# Genres Rec      | 0.99455    | 0.97859
# Genres F1       | 0.86190    | 0.84688
#
# ===== EPOCH 14 (Time: 65.40s, LR: 1.0e-03) =====
# Metric          | Train      | Valid
# -----------------------------------------
# Total           | 0.00268    | 0.00316
# Genres          | 0.00426    | 0.01314
# Numeric         | 0.00236    | 0.00116
# Genres Prc      | 0.77783    | 0.77046
# Genres Rec      | 0.99513    | 0.97771
# Genres F1       | 0.87309    | 0.86175
# * Best epoch so far!
#
# ===== EPOCH 15 (Time: 69.71s, LR: 1.0e-03) =====
# Metric          | Train      | Valid
# -----------------------------------------
# Total           | 0.00251    | 0.00310
# Genres          | 0.00390    | 0.01253
# Numeric         | 0.00223    | 0.00121
# Genres Prc      | 0.79349    | 0.78827
# Genres Rec      | 0.99550    | 0.97936
# Genres F1       | 0.88302    | 0.87344
# * Best epoch so far!
#
# ===== EPOCH 16 (Time: 74.06s, LR: 1.0e-03) =====
# Metric          | Train      | Valid
# -----------------------------------------
# Total           | 0.00241    | 0.00308
# Genres          | 0.00362    | 0.01206
# Numeric         | 0.00217    | 0.00128
# Genres Prc      | 0.80612    | 0.78471
# Genres Rec      | 0.99581    | 0.98006
# Genres F1       | 0.89092    | 0.87153
# * Best epoch so far!
#
# ===== EPOCH 17 (Time: 78.46s, LR: 1.0e-03) =====
# Metric          | Train      | Valid
# -----------------------------------------
# Total           | 0.00227    | 0.00313
# Genres          | 0.00329    | 0.01223
# Numeric         | 0.00207    | 0.00131
# Genres Prc      | 0.82109    | 0.80523
# Genres Rec      | 0.99628    | 0.97976
# Genres F1       | 0.90018    | 0.88393
#
# ===== EPOCH 18 (Time: 82.78s, LR: 1.0e-03) =====
# Metric          | Train      | Valid
# -----------------------------------------
# Total           | 0.00217    | 0.00292
# Genres          | 0.00311    | 0.01248
# Numeric         | 0.00198    | 0.00101
# Genres Prc      | 0.82914    | 0.80427
# Genres Rec      | 0.99634    | 0.98042
# Genres F1       | 0.90502    | 0.88362
# * Best epoch so far!
#
# ===== EPOCH 19 (Time: 87.06s, LR: 1.0e-03) =====
# Metric          | Train      | Valid
# -----------------------------------------
# Total           | 0.00210    | 0.00299
# Genres          | 0.00292    | 0.01223
# Numeric         | 0.00193    | 0.00114
# Genres Prc      | 0.83846    | 0.82288
# Genres Rec      | 0.99661    | 0.98010
# Genres F1       | 0.91067    | 0.89460
#
# ===== EPOCH 20 (Time: 91.36s, LR: 1.0e-03) =====
# Metric          | Train      | Valid
# -----------------------------------------
# Total           | 0.00198    | 0.00281
# Genres          | 0.00268    | 0.01186
# Numeric         | 0.00184    | 0.00100
# Genres Prc      | 0.85032    | 0.83414
# Genres Rec      | 0.99687    | 0.98017
# Genres F1       | 0.91773    | 0.90125
# * Best epoch so far!
#
# ===== EPOCH 21 (Time: 95.72s, LR: 1.0e-03) =====
# Metric          | Train      | Valid
# -----------------------------------------
# Total           | 0.00191    | 0.00288
# Genres          | 0.00252    | 0.01182
# Numeric         | 0.00179    | 0.00109
# Genres Prc      | 0.85826    | 0.81048
# Genres Rec      | 0.99705    | 0.98177
# Genres F1       | 0.92242    | 0.88790
#
# ===== EPOCH 22 (Time: 100.07s, LR: 1.0e-03) =====
# Metric          | Train      | Valid
# -----------------------------------------
# Total           | 0.00187    | 0.00289
# Genres          | 0.00241    | 0.01221
# Numeric         | 0.00176    | 0.00103
# Genres Prc      | 0.86396    | 0.84867
# Genres Rec      | 0.99715    | 0.98023
# Genres F1       | 0.92573    | 0.90969
#
# ===== EPOCH 23 (Time: 104.45s, LR: 1.0e-03) =====
# Metric          | Train      | Valid
# -----------------------------------------
# Total           | 0.00175    | 0.00278
# Genres          | 0.00222    | 0.01230
# Numeric         | 0.00165    | 0.00088
# Genres Prc      | 0.87417    | 0.85561
# Genres Rec      | 0.99736    | 0.97962
# Genres F1       | 0.93167    | 0.91340
# * Best epoch so far!
#
# ===== EPOCH 24 (Time: 108.78s, LR: 1.0e-03) =====
# Metric          | Train      | Valid
# -----------------------------------------
# Total           | 0.00173    | 0.00266
# Genres          | 0.00214    | 0.01154
# Numeric         | 0.00164    | 0.00088
# Genres Prc      | 0.87727    | 0.84645
# Genres Rec      | 0.99752    | 0.98301
# Genres F1       | 0.93350    | 0.90961
# * Best epoch so far!
#
# ===== EPOCH 25 (Time: 113.08s, LR: 1.0e-03) =====
# Metric          | Train      | Valid
# -----------------------------------------
# Total           | 0.00168    | 0.00267
# Genres          | 0.00201    | 0.01173
# Numeric         | 0.00161    | 0.00085
# Genres Prc      | 0.88475    | 0.85415
# Genres Rec      | 0.99758    | 0.98204
# Genres F1       | 0.93774    | 0.91362
#
# ===== EPOCH 26 (Time: 117.45s, LR: 1.0e-03) =====
# Metric          | Train      | Valid
# -----------------------------------------
# Total           | 0.00160    | 0.00267
# Genres          | 0.00193    | 0.01222
# Numeric         | 0.00153    | 0.00076
# Genres Prc      | 0.88848    | 0.87904
# Genres Rec      | 0.99761    | 0.98131
# Genres F1       | 0.93984    | 0.92734
#
# ===== EPOCH 27 (Time: 121.79s, LR: 1.0e-03) =====
# Metric          | Train      | Valid
# -----------------------------------------
# Total           | 0.00156    | 0.00301
# Genres          | 0.00185    | 0.01297
# Numeric         | 0.00151    | 0.00102
# Genres Prc      | 0.89357    | 0.83894
# Genres Rec      | 0.99772    | 0.98030
# Genres F1       | 0.94273    | 0.90410
#
# ===== EPOCH 28 (Time: 126.19s, LR: 1.0e-03) =====
# Metric          | Train      | Valid
# -----------------------------------------
# Total           | 0.00153    | 0.00276
# Genres          | 0.00181    | 0.01232
# Numeric         | 0.00147    | 0.00085
# Genres Prc      | 0.89483    | 0.87696
# Genres Rec      | 0.99773    | 0.98069
# Genres F1       | 0.94345    | 0.92591
#
# ===== EPOCH 29 (Time: 130.59s, LR: 1.0e-03) =====
# Metric          | Train      | Valid
# -----------------------------------------
# Total           | 0.00148    | 0.00281
# Genres          | 0.00169    | 0.01218
# Numeric         | 0.00143    | 0.00093
# Genres Prc      | 0.90195    | 0.87958
# Genres Rec      | 0.99791    | 0.98109
# Genres F1       | 0.94746    | 0.92755
#
# ===== EPOCH 30 (Time: 134.97s, LR: 5.0e-04) =====
# Metric          | Train      | Valid
# -----------------------------------------
# Total           | 0.00147    | 0.00287
# Genres          | 0.00170    | 0.01286
# Numeric         | 0.00143    | 0.00088
# Genres Prc      | 0.90124    | 0.87598
# Genres Rec      | 0.99785    | 0.98126
# Genres F1       | 0.94704    | 0.92562
#
# ===== EPOCH 31 (Time: 139.38s, LR: 5.0e-04) =====
# Metric          | Train      | Valid
# -----------------------------------------
# Total           | 0.00100    | 0.00263
# Genres          | 0.00107    | 0.01375
# Numeric         | 0.00099    | 0.00041
# Genres Prc      | 0.93699    | 0.91869
# Genres Rec      | 0.99869    | 0.98037
# Genres F1       | 0.96683    | 0.94851
# * Best epoch so far!
#
# ===== EPOCH 32 (Time: 143.81s, LR: 5.0e-04) =====
# Metric          | Train      | Valid
# -----------------------------------------
# Total           | 0.00098    | 0.00259
# Genres          | 0.00099    | 0.01341
# Numeric         | 0.00098    | 0.00043
# Genres Prc      | 0.94113    | 0.92106
# Genres Rec      | 0.99869    | 0.98088
# Genres F1       | 0.96904    | 0.95002
# * Best epoch so far!
#
# ===== EPOCH 33 (Time: 148.19s, LR: 5.0e-04) =====
# Metric          | Train      | Valid
# -----------------------------------------
# Total           | 0.00100    | 0.00269
# Genres          | 0.00098    | 0.01366
# Numeric         | 0.00100    | 0.00050
# Genres Prc      | 0.94126    | 0.90955
# Genres Rec      | 0.99875    | 0.98158
# Genres F1       | 0.96914    | 0.94418
#
# ===== EPOCH 34 (Time: 152.71s, LR: 5.0e-04) =====
# Metric          | Train      | Valid
# -----------------------------------------
# Total           | 0.00099    | 0.00263
# Genres          | 0.00096    | 0.01377
# Numeric         | 0.00100    | 0.00040
# Genres Prc      | 0.94234    | 0.91531
# Genres Rec      | 0.99877    | 0.98153
# Genres F1       | 0.96972    | 0.94725
#
# ===== EPOCH 35 (Time: 157.12s, LR: 5.0e-04) =====
# Metric          | Train      | Valid
# -----------------------------------------
# Total           | 0.00099    | 0.00279
# Genres          | 0.00095    | 0.01424
# Numeric         | 0.00100    | 0.00050
# Genres Prc      | 0.94246    | 0.91330
# Genres Rec      | 0.99875    | 0.98079
# Genres F1       | 0.96977    | 0.94583
#
# ===== EPOCH 36 (Time: 161.49s, LR: 5.0e-04) =====
# Metric          | Train      | Valid
# -----------------------------------------
# Total           | 0.00098    | 0.00276
# Genres          | 0.00093    | 0.01390
# Numeric         | 0.00099    | 0.00053
# Genres Prc      | 0.94435    | 0.91948
# Genres Rec      | 0.99878    | 0.98124
# Genres F1       | 0.97078    | 0.94934
#
# ===== EPOCH 37 (Time: 165.91s, LR: 5.0e-04) =====
# Metric          | Train      | Valid
# -----------------------------------------
# Total           | 0.00096    | 0.00272
# Genres          | 0.00090    | 0.01404
# Numeric         | 0.00097    | 0.00046
# Genres Prc      | 0.94580    | 0.91208
# Genres Rec      | 0.99881    | 0.98192
# Genres F1       | 0.97156    | 0.94570
#
# ===== EPOCH 38 (Time: 170.27s, LR: 2.5e-04) =====
# Metric          | Train      | Valid
# -----------------------------------------
# Total           | 0.00095    | 0.00291
# Genres          | 0.00089    | 0.01538
# Numeric         | 0.00096    | 0.00042
# Genres Prc      | 0.94615    | 0.92720
# Genres Rec      | 0.99882    | 0.97881
# Genres F1       | 0.97175    | 0.95229
#
# ===== EPOCH 39 (Time: 174.71s, LR: 2.5e-04) =====
# Metric          | Train      | Valid
# -----------------------------------------
# Total           | 0.00076    | 0.00275
# Genres          | 0.00065    | 0.01499
# Numeric         | 0.00079    | 0.00030
# Genres Prc      | 0.96140    | 0.93315
# Genres Rec      | 0.99920    | 0.98091
# Genres F1       | 0.97992    | 0.95642
#
# ===== EPOCH 40 (Time: 179.09s, LR: 2.5e-04) =====
# Metric          | Train      | Valid
# -----------------------------------------
# Total           | 0.00076    | 0.00280
# Genres          | 0.00062    | 0.01524
# Numeric         | 0.00078    | 0.00031
# Genres Prc      | 0.96267    | 0.94068
# Genres Rec      | 0.99923    | 0.98076
# Genres F1       | 0.98060    | 0.96029
#
# ===== EPOCH 41 (Time: 183.55s, LR: 2.5e-04) =====
# Metric          | Train      | Valid
# -----------------------------------------
# Total           | 0.00075    | 0.00286
# Genres          | 0.00061    | 0.01565
# Numeric         | 0.00078    | 0.00030
# Genres Prc      | 0.96338    | 0.93814
# Genres Rec      | 0.99924    | 0.98061
# Genres F1       | 0.98097    | 0.95889
#
# ===== EPOCH 42 (Time: 187.97s, LR: 2.5e-04) =====
# Metric          | Train      | Valid
# -----------------------------------------
# Total           | 0.00075    | 0.00295
# Genres          | 0.00058    | 0.01608
# Numeric         | 0.00078    | 0.00033
# Genres Prc      | 0.96450    | 0.94752
# Genres Rec      | 0.99923    | 0.98029
# Genres F1       | 0.98155    | 0.96362
#
# ===== EPOCH 43 (Time: 192.36s, LR: 2.5e-04) =====
# Metric          | Train      | Valid
# -----------------------------------------
# Total           | 0.00074    | 0.00286
# Genres          | 0.00058    | 0.01559
# Numeric         | 0.00077    | 0.00031
# Genres Prc      | 0.96462    | 0.94277
# Genres Rec      | 0.99925    | 0.98042
# Genres F1       | 0.98162    | 0.96122
#
# ===== EPOCH 44 (Time: 196.77s, LR: 1.3e-04) =====
# Metric          | Train      | Valid
# -----------------------------------------
# Total           | 0.00074    | 0.00293
# Genres          | 0.00060    | 0.01602
# Numeric         | 0.00076    | 0.00031
# Genres Prc      | 0.96326    | 0.94272
# Genres Rec      | 0.99919    | 0.97900
# Genres F1       | 0.98089    | 0.96051
#
# ===== EPOCH 45 (Time: 201.23s, LR: 1.3e-04) =====
# Metric          | Train      | Valid
# -----------------------------------------
# Total           | 0.00066    | 0.00296
# Genres          | 0.00048    | 0.01650
# Numeric         | 0.00069    | 0.00025
# Genres Prc      | 0.97118    | 0.94771
# Genres Rec      | 0.99941    | 0.97992
# Genres F1       | 0.98509    | 0.96354
#
# ===== EPOCH 46 (Time: 205.72s, LR: 1.3e-04) =====
# Metric          | Train      | Valid
# -----------------------------------------
# Total           | 0.00065    | 0.00299
# Genres          | 0.00045    | 0.01673
# Numeric         | 0.00069    | 0.00024
# Genres Prc      | 0.97288    | 0.95100
# Genres Rec      | 0.99944    | 0.98033
# Genres F1       | 0.98597    | 0.96543
#
# ===== EPOCH 47 (Time: 210.09s, LR: 1.3e-04) =====
# Metric          | Train      | Valid
# -----------------------------------------
# Total           | 0.00064    | 0.00296
# Genres          | 0.00045    | 0.01664
# Numeric         | 0.00068    | 0.00023
# Genres Prc      | 0.97321    | 0.94860
# Genres Rec      | 0.99943    | 0.98027
# Genres F1       | 0.98614    | 0.96417
#
# ===== EPOCH 48 (Time: 214.46s, LR: 1.3e-04) =====
# Metric          | Train      | Valid
# -----------------------------------------
# Total           | 0.00064    | 0.00298
# Genres          | 0.00045    | 0.01669
# Numeric         | 0.00068    | 0.00024
# Genres Prc      | 0.97305    | 0.94942
# Genres Rec      | 0.99944    | 0.98076
# Genres F1       | 0.98606    | 0.96483
#
# ===== EPOCH 49 (Time: 218.92s, LR: 1.3e-04) =====
# Metric          | Train      | Valid
# -----------------------------------------
# Total           | 0.00064    | 0.00299
# Genres          | 0.00044    | 0.01674
# Numeric         | 0.00068    | 0.00025
# Genres Prc      | 0.97291    | 0.95036
# Genres Rec      | 0.99941    | 0.98051
# Genres F1       | 0.98597    | 0.96519
#
# ===== EPOCH 50 (Time: 223.50s, LR: 6.3e-05) =====
# Metric          | Train      | Valid
# -----------------------------------------
# Total           | 0.00063    | 0.00297
# Genres          | 0.00046    | 0.01660
# Numeric         | 0.00067    | 0.00024
# Genres Prc      | 0.97239    | 0.94753
# Genres Rec      | 0.99939    | 0.98034
# Genres F1       | 0.98570    | 0.96365
#
# ===== EPOCH 51 (Time: 228.03s, LR: 6.3e-05) =====
# Metric          | Train      | Valid
# -----------------------------------------
# Total           | 0.00059    | 0.00297
# Genres          | 0.00039    | 0.01675
# Numeric         | 0.00064    | 0.00021
# Genres Prc      | 0.97678    | 0.95176
# Genres Rec      | 0.99952    | 0.98106
# Genres F1       | 0.98801    | 0.96618
#
# ===== EPOCH 52 (Time: 232.41s, LR: 6.3e-05) =====
# Metric          | Train      | Valid
# -----------------------------------------
# Total           | 0.00059    | 0.00306
# Genres          | 0.00038    | 0.01739
# Numeric         | 0.00063    | 0.00020
# Genres Prc      | 0.97718    | 0.95506
# Genres Rec      | 0.99954    | 0.97998
# Genres F1       | 0.98823    | 0.96735
#
# ===== EPOCH 53 (Time: 236.82s, LR: 6.3e-05) =====
# Metric          | Train      | Valid
# -----------------------------------------
# Total           | 0.00059    | 0.00310
# Genres          | 0.00037    | 0.01752
# Numeric         | 0.00063    | 0.00021
# Genres Prc      | 0.97737    | 0.95603
# Genres Rec      | 0.99952    | 0.97996
# Genres F1       | 0.98832    | 0.96784
#
# ===== EPOCH 54 (Time: 241.20s, LR: 6.3e-05) =====
# Metric          | Train      | Valid
# -----------------------------------------
# Total           | 0.00058    | 0.00309
# Genres          | 0.00037    | 0.01736
# Numeric         | 0.00063    | 0.00023
# Genres Prc      | 0.97763    | 0.95339
# Genres Rec      | 0.99955    | 0.98086
# Genres F1       | 0.98846    | 0.96693
#
# ===== EPOCH 55 (Time: 245.58s, LR: 6.3e-05) =====
# Metric          | Train      | Valid
# -----------------------------------------
# Total           | 0.00058    | 0.00308
# Genres          | 0.00037    | 0.01741
# Numeric         | 0.00063    | 0.00022
# Genres Prc      | 0.97719    | 0.95283
# Genres Rec      | 0.99953    | 0.98060
# Genres F1       | 0.98823    | 0.96651
#
# ===== EPOCH 56 (Time: 249.94s, LR: 3.1e-05) =====
# Metric          | Train      | Valid
# -----------------------------------------
# Total           | 0.00058    | 0.00313
# Genres          | 0.00037    | 0.01764
# Numeric         | 0.00062    | 0.00023
# Genres Prc      | 0.97777    | 0.95382
# Genres Rec      | 0.99951    | 0.98051
# Genres F1       | 0.98851    | 0.96698
#
# ===== EPOCH 57 (Time: 254.36s, LR: 3.1e-05) =====
# Metric          | Train      | Valid
# -----------------------------------------
# Total           | 0.00056    | 0.00311
# Genres          | 0.00034    | 0.01767
# Numeric         | 0.00060    | 0.00020
# Genres Prc      | 0.97914    | 0.95652
# Genres Rec      | 0.99959    | 0.98054
# Genres F1       | 0.98926    | 0.96838
#
# ===== EPOCH 58 (Time: 258.80s, LR: 3.1e-05) =====
# Metric          | Train      | Valid
# -----------------------------------------
# Total           | 0.00056    | 0.00313
# Genres          | 0.00034    | 0.01778
# Numeric         | 0.00060    | 0.00020
# Genres Prc      | 0.97947    | 0.95534
# Genres Rec      | 0.99955    | 0.98056
# Genres F1       | 0.98941    | 0.96778
#
# ===== EPOCH 59 (Time: 263.20s, LR: 3.1e-05) =====
# Metric          | Train      | Valid
# -----------------------------------------
# Total           | 0.00055    | 0.00314
# Genres          | 0.00033    | 0.01785
# Numeric         | 0.00060    | 0.00020
# Genres Prc      | 0.98025    | 0.95502
# Genres Rec      | 0.99960    | 0.98053
# Genres F1       | 0.98983    | 0.96760
# Restored best model (valid loss: 0.00259, epoch: 32)

# %% [markdown]
# # Profiling

# %%
import matplotlib.pyplot as plt


def plot_training_results(history):
    metrics = list(history[0][0].keys())
    num_metrics = len(metrics)
    
    cols = 2
    rows = (num_metrics + 1) // 2
    fig, axes = plt.subplots(rows, cols, figsize=(15, 4 * rows))
    axes = axes.flatten()

    for i, metric in enumerate(metrics):
        train_vals = [h[0][metric] for h in history]
        valid_vals = [h[1][metric] for h in history]
        
        ax = axes[i]
        ax.plot(train_vals, label="Train", marker="o", markersize=3)
        ax.plot(valid_vals, label="Valid", linestyle="--", marker="x", markersize=3)
        
        title = metric.replace("_", " ").title()
        ax.set_title(f"Loss: {title}")
        ax.set_xlabel("Epoch")
        ax.set_ylabel("Loss Value")
        ax.semilogy()
        ax.legend()
        ax.grid(True, alpha=0.3)
        if train_vals[0] / (train_vals[-1] + 1e-9) > 100:
            ax.set_yscale("log")

    for j in range(i + 1, len(axes)):
        fig.delaxes(axes[j])

    plt.tight_layout()
    plt.show()

# Use it like this:
plot_training_results(history)

# %%
import torch.nn.functional as F


def get_recommender(
    model: nn.Module, 
    device: torch.device, 
    df: pd.DataFrame, 
    genre2idx: dict, 
):
    embeddings = [None]
    
    @torch.no_grad()
    def get_all_embeddings():
        dataset = TrackDataset(df, genre2idx=genre2idx)
        dl = DataLoader(dataset, batch_size=1024, shuffle=False, num_workers=20, collate_fn=collate_fn)
        ys = []
        model.eval()
        for batch in dl:
            batch = {k: v.to(device) for k, v in batch.items()}
            ys.append(model.encode(batch))
        return torch.cat(ys, dim=0)

    def recommend(artist: str, track: str, n=10):
        match = df[(df["artist_name"] == artist) & (df["track_name"] == track)]
        if match.empty: 
            return "Track not found."
        idx = match.index[0]
        query_vec = Z[idx].unsqueeze(0)
        sim = F.cosine_similarity(query_vec, Z)
        scores, top_indices = torch.topk(sim, k=n+1)
        similiar_df = df.iloc[top_indices[1:].cpu()]
        return pd.DataFrame({
            "artist_name": similiar_df["artist_name"],
            "track_name": similiar_df["track_name"],
            "score": scores.cpu()[1:],
        })
        
    Z = get_all_embeddings()        
    return recommend

recommend = get_recommender(model, device, df, genre2idx)

# %%
recommend("Joy Division", "Disorder", 10)
# Out:
#              artist_name                      track_name     score
# 544175      Joy Division        Disorder - 2007 Remaster  0.863247
# 230367   Casket Cassette                         Bouquet  0.827087
# 362613      Joy Division  Disorder - 2019 Digital Master  0.826673
# 533676      Joy Division         Love Will Tear Us Apart  0.797702
# 196214  all under heaven     Desperately Seeking Answers  0.783008
# 146247        Vogue.Noir               Love Like Vampire  0.772631
# 442169          The Cure                  Play For Today  0.772282
# 332661       Noé Preszow        Prière de n'pas déranger  0.769543
# 201009       Suffocation             Pierced from Within  0.764108
# 8459         アトラスサウンドチーム                     Battle - b2  0.755307

# %%
recommend("MF DOOM", "Doomsday", 10)
# Out:
#                     artist_name  \
# 402407  People Under The Stairs
# 511017                  Mos Def
# 115463                    JAY-Z
# 343602                  MF DOOM
# 465905             Cypress Hill
# 247571     A Tribe Called Quest
# 334495               Lucky Dube
# 60915              The Pharcyde
# 372844             Brand Nubian
# 499110                    Rakim
#
#                                            track_name     score
# 402407                          San Francisco Knights  0.892313
# 511017                                    Mathematics  0.863079
# 115463                            Money Ain't A Thang  0.855457
# 343602                                     The Finest  0.850390
# 465905  Siempre Peligroso (feat. Fermin IV Caballero)  0.850012
# 247571                              God Lives Through  0.848084
# 334495                         Don't Cry (Remastered)  0.846102
# 60915                             4 Better Or 4 Worse  0.841684
# 372844                                   Word is Bond  0.834743
# 499110                               Guess Who's Back  0.831710

# %%
recommend("CCCP – Fedeli Alla Linea", "Io Sto Bene", 10)
# Out:
#                    artist_name                          track_name     score
# 308084           Tiziano Ferro                             Incanto  0.892017
# 164350           ItaloBrothers                    Moonlight Shadow  0.869717
# 84426              Simon Webbe                 Coming Around Again  0.850497
# 432811              Ermal Meta                      Vietato morire  0.839594
# 308103  Michael Learns To Rock               It's Gonna Make Sense  0.836617
# 536502           Beach Weather  Sex, Drugs, Etc. - Sped Up Version  0.832802
# 431065           Blake Shelton     Hell Right (feat. Trace Adkins)  0.832504
# 273225               moondoggy                            Passport  0.829901
# 330895                      G2                            Detonate  0.825171
# 371224             Keith Urban                          We Were Us  0.824902
