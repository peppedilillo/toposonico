# %% [markdown]
# # Training Data Exploration
#
# Explore the parquet training table extracted for the autoencoder.

# %%
from pathlib import Path
import pandas as pd

data_path = Path("..") / "data" / f"training_pop50.parquet"
df = pd.read_parquet(data_path)
print(f"Loaded {len(df):,} tracks from {data_path}")
# Out:
# Loaded 186,960 tracks from ../data/training_pop50.parquet

# %% [markdown]
# ## Basic Info

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 186960 entries, 0 to 186959
# Data columns (total 33 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   track_rowid             186960 non-null  int64
#  1   track_name              186960 non-null  object
#  2   artist_name             186960 non-null  object
#  3   artist_rowid            186960 non-null  int64
#  4   album_rowid             186960 non-null  int64
#  5   album_name              186960 non-null  object
#  6   album_type              186960 non-null  object
#  7   label                   186960 non-null  object
#  8   release_date            186960 non-null  object
#  9   release_date_precision  186960 non-null  object
#  10  id_isrc                 186947 non-null  object
#  11  id_upc                  186297 non-null  object
#  12  time_signature          186960 non-null  int64
#  13  tempo                   186960 non-null  float64
#  14  key                     186960 non-null  int64
#  15  mode                    186960 non-null  int64
#  16  danceability            186960 non-null  float64
#  17  energy                  186960 non-null  float64
#  18  loudness                186960 non-null  float64
#  19  speechiness             186960 non-null  float64
#  20  acousticness            186960 non-null  float64
#  21  instrumentalness        186960 non-null  float64
#  22  liveness                186960 non-null  float64
#  23  valence                 186960 non-null  float64
#  24  explicit                186960 non-null  int64
#  25  track_popularity        186960 non-null  int64
#  26  artist_popularity       186960 non-null  int64
#  27  artist_followers        186960 non-null  int64
#  28  album_popularity        186960 non-null  int64
#  29  duration_ms             186960 non-null  int64
#  30  track_number            186960 non-null  int64
#  31  disc_number             186960 non-null  int64
#  32  total_tracks            186960 non-null  int64
# dtypes: float64(9), int64(15), object(9)
# memory usage: 47.1+ MB

# %%
df.head(10)
# Out:
#    track_rowid                       track_name     artist_name  artist_rowid  \
# 0            5             I Just Missed A Call            NOTD       1853555
# 1           28                          IT girl            JADE       5196797
# 2          129                         Betrayal  Warren Zeiders        219151
# 3          138                       Withdrawal  Warren Zeiders        219151
# 4          204                         Afterall          Saveus       4490251
# 5          412  Eh, Eh (Nothing Else I Can Say)       Lady Gaga       5908777
# 6          416                       Starstruck       Lady Gaga       5908777
# 7          497                 Diggin' My Grave       Lady Gaga       5908777
# 8          564                           Mobile   Avril Lavigne       6320580
# 9          570                    Nobody's Fool   Avril Lavigne       6320580
#
#    album_rowid                         album_name album_type  \
# 0            2                      Digital Notes     single
# 1           15            FUFN (Fuck You For Now)     single
# 2           37          Relapse, Lies, & Betrayal      album
# 3           37          Relapse, Lies, & Betrayal      album
# 4           62                           Afterall     single
# 5          114  The Fame Monster (Deluxe Edition)      album
# 6          114  The Fame Monster (Deluxe Edition)      album
# 7          120          A Star Is Born Soundtrack      album
# 8          124                             Let Go      album
# 9          124                             Let Go      album
#
#                 label release_date release_date_precision  ... valence  \
# 0  Universal Music AB   2025-03-14                    day  ...   0.702
# 1   RCA Records Label   2025-03-14                    day  ...   0.522
# 2      Warner Records   2025-03-14                    day  ...   0.221
# 3      Warner Records   2025-03-14                    day  ...   0.339
# 4    The Bank Records   2025-03-14                    day  ...   0.322
# 5          Interscope   2009-11-05                    day  ...   0.816
# 6          Interscope   2009-11-05                    day  ...   0.509
# 7  A Star is Born OST   2018-10-05                    day  ...   0.549
# 8              Arista   2002-06-04                    day  ...   0.634
# 9              Arista   2002-06-04                    day  ...   0.459
#
#   explicit  track_popularity  artist_popularity  artist_followers  \
# 0        0                51                 62            317626
# 1        1                51                 64            226527
# 2        0                51                 75            934909
# 3        0                51                 75            934909
# 4        0                51                 47             40479
# 5        0                51                 94          36284092
# 6        0                51                 94          36284092
# 7        0                51                 94          36284092
# 8        0                51                 78          11632962
# 9        0                51                 78          11632962
#
#    album_popularity  duration_ms  track_number  disc_number  total_tracks
# 0                42       146424             4            1             6
# 1                51       153718             3            1             5
# 2                53       180282             3            1            21
# 3                53       185680            12            1            21
# 4                30       202688             1            1             1
# 5                77       175360             5            2            23
# 6                77       217120             9            2            23
# 7                76       237306            15            1            34
# 8                76       211933             5            1            13
# 9                76       237333            11            1            13
#
# [10 rows x 33 columns]

# %% [markdown]
# ## Audio Features Statistics

# %%
audio_features = [
    "danceability", "energy", "loudness", "speechiness",
    "acousticness", "instrumentalness", "liveness", "valence",
    "tempo", "time_signature", "key", "mode"
]

df[audio_features].describe()
# Out:
#         danceability         energy       loudness    speechiness  \
# count  186960.000000  186960.000000  186960.000000  186960.000000
# mean        0.610505       0.611848      -8.652004       0.097024
# std         0.177748       0.239374       6.659299       0.105514
# min         0.000000       0.000019     -54.376000       0.000000
# 25%         0.509000       0.478000      -9.402000       0.036700
# 50%         0.633000       0.649000      -6.826000       0.052300
# 75%         0.740000       0.793000      -5.089000       0.107000
# max         0.988000       1.000000       4.918000       0.967000
#
#         acousticness  instrumentalness       liveness        valence  \
# count  186960.000000     186960.000000  186960.000000  186960.000000
# mean        0.328371          0.112640       0.190401       0.498221
# std         0.310617          0.277754       0.160555       0.255709
# min         0.000000          0.000000       0.000000       0.000000
# 25%         0.052800          0.000000       0.097900       0.298000
# 50%         0.226000          0.000005       0.124000       0.498000
# 75%         0.556000          0.002840       0.231000       0.704000
# max         0.996000          1.000000       1.000000       1.000000
#
#                tempo  time_signature            key           mode
# count  186960.000000   186960.000000  186960.000000  186960.000000
# mean      121.062657        3.909933       5.279899       0.601450
# std        29.587736        0.420870       3.584909       0.489601
# min         0.000000        0.000000       0.000000       0.000000
# 25%        97.749000        4.000000       2.000000       0.000000
# 50%       120.493000        4.000000       5.000000       1.000000
# 75%       139.999000        4.000000       8.000000       1.000000
# max       243.372000        5.000000      11.000000       1.000000

# %% [markdown]
# ## Popularity & Metadata Statistics

# %%
metadata_cols = [
    "track_popularity", "album_popularity", "artist_popularity",
    "artist_followers", "duration_ms"
]

df[metadata_cols].describe()
# Out:
#        track_popularity  album_popularity  artist_popularity  \
# count     186960.000000     186960.000000      186960.000000
# mean          57.580375         53.252583          64.484783
# std            6.415878         10.784420          13.537161
# min           51.000000          0.000000           0.000000
# 25%           53.000000         44.000000          55.000000
# 50%           56.000000         52.000000          64.000000
# 75%           61.000000         60.000000          74.000000
# max          100.000000        100.000000         100.000000
#
#        artist_followers   duration_ms
# count      1.869600e+05  1.869600e+05
# mean       5.414104e+06  2.084534e+05
# std        1.484444e+07  8.058680e+04
# min        0.000000e+00  3.000100e+04
# 25%        1.182300e+05  1.653600e+05
# 50%        7.811330e+05  1.999635e+05
# 75%        3.872564e+06  2.388138e+05
# max        1.411744e+08  4.500036e+06

# %% [markdown]
# ## Categorical Columns

# %%
print("Album types:")
print(df["album_type"].value_counts())
print()
print("Explicit:")
print(df["explicit"].value_counts())
print()
print("Mode (0=minor, 1=major):")
print(df["mode"].value_counts())
# Out:
# Album types:
# album_type
# album          105137
# single          76404
# compilation      5419
# Name: count, dtype: int64
#
# Explicit:
# explicit
# 0    148697
# 1     38263
# Name: count, dtype: int64
#
# Mode (0=minor, 1=major):
# mode
# 1    112447
# 0     74513
# Name: count, dtype: int64

# %% [markdown]
# ## Genre Analysis

# %%
# Tracks without genres
no_genre = df["genres"].isna() | (df["genres"] == "")
print(f"Tracks without genres: {no_genre.sum():,} ({no_genre.mean()*100:.1f}%)")

# %%
# Most common genres
all_genres = df["genres"].dropna().str.split(";").explode()
print(f"Total genre tags: {len(all_genres):,}")
print(f"Unique genres: {all_genres.nunique():,}")
print()
print("Top 20 genres:")
all_genres.value_counts().head(20)

# %% [markdown]
# ## Missing Values

# %%
missing = df.isna().sum()
missing[missing > 0]
# Out:
# id_isrc     13
# id_upc     663
# dtype: int64

# %% [markdown]
# ## Top Artists by Track Count

# %%
df.groupby("artist_name").size().sort_values(ascending=False).head(20)
# Out:
# artist_name
# Taylor Swift                  532
# Drake                         361
# The Weeknd                    263
# Ariana Grande                 251
# Pritam                        246
# Eminem                        236
# Stray Kids                    228
# BTS                           222
# $uicideboy$                   209
# Future                        208
# Anirudh Ravichander           198
# The Beatles                   187
# Kendrick Lamar                182
# Lana Del Rey                  177
# Henrique & Juliano            177
# Beyoncé                       176
# Kanye West                    175
# Morgan Wallen                 166
# SZA                           162
# YoungBoy Never Broke Again    162
# dtype: int64

# %% [markdown]
# ## Release Date Distribution

# %%
# Extract year from release_date
df["release_year"] = pd.to_datetime(df["release_date"], errors="coerce").dt.year
df["release_year"].value_counts().sort_index().tail(20)
# Out:
# release_year
# 2006.0     1860
# 2007.0     1857
# 2008.0     1836
# 2009.0     1994
# 2010.0     2225
# 2011.0     2336
# 2012.0     2798
# 2013.0     3072
# 2014.0     3505
# 2015.0     4271
# 2016.0     5088
# 2017.0     6051
# 2018.0     7100
# 2019.0     8335
# 2020.0     9444
# 2021.0    11799
# 2022.0    13268
# 2023.0    18900
# 2024.0    29782
# 2025.0    21981
# Name: count, dtype: int64

# %% [markdown]
# ## Correlation Matrix (Audio Features)

# %%
df[audio_features].corr().round(2)
# Out:
#                   danceability  energy  loudness  speechiness  acousticness  \
# danceability              1.00    0.30      0.48         0.22         -0.30
# energy                    0.30    1.00      0.75         0.10         -0.71
# loudness                  0.48    0.75      1.00         0.09         -0.59
# speechiness               0.22    0.10      0.09         1.00         -0.11
# acousticness             -0.30   -0.71     -0.59        -0.11          1.00
# instrumentalness         -0.39   -0.42     -0.69        -0.14          0.38
# liveness                 -0.09    0.22      0.10         0.06         -0.10
# valence                   0.53    0.41      0.41         0.09         -0.24
# tempo                    -0.01    0.21      0.20         0.04         -0.17
# time_signature            0.19    0.16      0.18         0.06         -0.16
# key                       0.04    0.05      0.05         0.01         -0.03
# mode                     -0.11   -0.11     -0.09        -0.08          0.09
#
#                   instrumentalness  liveness  valence  tempo  time_signature  \
# danceability                 -0.39     -0.09     0.53  -0.01            0.19
# energy                       -0.42      0.22     0.41   0.21            0.16
# loudness                     -0.69      0.10     0.41   0.20            0.18
# speechiness                  -0.14      0.06     0.09   0.04            0.06
# acousticness                  0.38     -0.10    -0.24  -0.17           -0.16
# instrumentalness              1.00     -0.05    -0.36  -0.14           -0.13
# liveness                     -0.05      1.00     0.02   0.02            0.01
# valence                      -0.36      0.02     1.00   0.11            0.09
# tempo                        -0.14      0.02     0.11   1.00            0.00
# time_signature               -0.13      0.01     0.09   0.00            1.00
# key                          -0.03     -0.00     0.05   0.01            0.01
# mode                          0.05      0.00    -0.05   0.00           -0.04
#
#                    key  mode
# danceability      0.04 -0.11
# energy            0.05 -0.11
# loudness          0.05 -0.09
# speechiness       0.01 -0.08
# acousticness     -0.03  0.09
# instrumentalness -0.03  0.05
# liveness         -0.00  0.00
# valence           0.05 -0.05
# tempo             0.01  0.00
# time_signature    0.01 -0.04
# key               1.00 -0.14
# mode             -0.14  1.00
